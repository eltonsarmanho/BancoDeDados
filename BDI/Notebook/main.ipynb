# %% [markdown]
# # 🔄 Engenharia Reversa em Banco de Dados
# ## De Classes Python para Tabelas SQL com ORM
#
# ---
#
# ### 📚 **Objetivo do Notebook**
#
# Este notebook apresenta os conceitos de **Engenharia Reversa em Banco de Dados**, explorando como transformar classes Python em tabelas de banco de dados utilizando ferramentas ORM (Object-Relational Mapping).
#
# **Tópicos Abordados:**
# 1. ✅ Conceitos de Engenharia Reversa em BD
# 2. ✅ O que é ORM e sua importância
# 3. ✅ Principais bibliotecas Python para ORM
# 4. ✅ Vantagens e Desvantagens
# 5. ✅ Exemplos práticos com SQLAlchemy e Django ORM
# 6. ✅ Comparação entre diferentes ORMs

# %% [markdown]
# ## 1️⃣ O que é Engenharia Reversa em Banco de Dados?
#
# ---
#
# ### 🎯 **Definição**
#
# **Engenharia Reversa em Banco de Dados** é o processo de gerar automaticamente:
# - Tabelas no banco de dados a partir de **classes/modelos** no código
# - Relacionamentos entre tabelas baseados nas associações entre objetos
# - Constraints e índices baseados nas definições de classes
#
# ### 🔄 **Fluxo Tradicional vs. Engenharia Reversa**
#
# ```
# 📌 Abordagem Tradicional (Database-First):
#    SQL (CREATE TABLE) → Estrutura BD → Código da Aplicação
#
# 🚀 Engenharia Reversa (Code-First):
#    Classes Python → ORM → Tabelas no Banco de Dados
# ```
#
# ### 💡 **Por que usar?**
#
# 1. **Desenvolvimento Ágil**: Alterações no modelo são feitas no código
# 2. **Versionamento**: Mudanças no BD ficam no controle de versão (Git)
# 3. **Portabilidade**: Mesmo código funciona com diferentes SGBDs
# 4. **Manutenibilidade**: Código orientado a objetos é mais fácil de manter
# 5. **Migrações Automáticas**: Frameworks geram scripts de migração automaticamente

# %% [markdown]
# ## 2️⃣ O que é ORM (Object-Relational Mapping)?
#
# ---
#
# ### 📖 **Definição**
#
# **ORM** é uma técnica de programação que permite:
# - Mapear objetos de classes para linhas de tabelas
# - Converter operações orientadas a objetos em queries SQL
# - Abstrair a comunicação com o banco de dados
#
# ### 🔗 **Mapeamento Objeto-Relacional**
#
# | Conceito OO | Conceito Relacional |
# |-------------|---------------------|
# | Classe | Tabela |
# | Atributo | Coluna |
# | Objeto (instância) | Linha (registro) |
# | Relacionamento | Foreign Key |
# | Herança | Joins / Tabelas separadas |
#
# ### 🎨 **Exemplo Conceitual**
#
# ```python
# # Classe Python
# class Pessoa:
#     nome: str
#     idade: int
#     email: str
#
# # ↓ ORM faz a conversão ↓
#
# # SQL gerado automaticamente
# CREATE TABLE pessoa (
#     id INTEGER PRIMARY KEY,
#     nome VARCHAR(100),
#     idade INTEGER,
#     email VARCHAR(100)
# );
# ```

# %% [markdown]
# ## 3️⃣ Principais Bibliotecas Python para ORM
#
# ---
#
# ### 📦 **1. SQLAlchemy**
#
# - **Mais popular e completo** ORM para Python
# - Suporta múltiplos bancos de dados (PostgreSQL, MySQL, SQLite, Oracle, etc.)
# - Possui duas formas de uso: ORM e Core (SQL Expression Language)
# - Altamente configurável e flexível
#
# **Instalação:**
# ```bash
# pip install sqlalchemy
# ```
#
# ---
#
# ### 🎯 **2. Django ORM**
#
# - ORM integrado ao framework Django
# - Muito fácil de usar para iniciantes
# - Migrações automáticas muito robustas
# - Limitado ao ecossistema Django
#
# **Instalação:**
# ```bash
# pip install django
# ```
#
# ---
#
# ### ⚡ **3. Peewee**
#
# - ORM leve e simples
# - Sintaxe mais "pythônica"
# - Ótimo para projetos pequenos e médios
# - Menos recursos que SQLAlchemy
#
# **Instalação:**
# ```bash
# pip install peewee
# ```
#
# ---
#
# ### 🚀 **4. Tortoise ORM**
#
# - ORM assíncrono (async/await)
# - Inspirado no Django ORM
# - Ideal para aplicações assíncronas (FastAPI, asyncio)
# - Relativamente novo
#
# **Instalação:**
# ```bash
# pip install tortoise-orm
# ```
#
# ---
#
# ### 🔧 **5. Pony ORM**
#
# - Sintaxe declarativa única usando geradores Python
# - Otimização automática de queries
# - Menos popular que SQLAlchemy
#
# **Instalação:**
# ```bash
# pip install pony
# ```

# %% [markdown]
# ## 4️⃣ Comparação entre ORMs Python
#
# ---
#
# | Característica | SQLAlchemy | Django ORM | Peewee | Tortoise ORM |
# |----------------|------------|------------|--------|--------------|
# | **Popularidade** | ⭐⭐⭐⭐⭐ | ⭐⭐⭐⭐⭐ | ⭐⭐⭐ | ⭐⭐ |
# | **Facilidade** | ⭐⭐⭐ | ⭐⭐⭐⭐⭐ | ⭐⭐⭐⭐ | ⭐⭐⭐⭐ |
# | **Flexibilidade** | ⭐⭐⭐⭐⭐ | ⭐⭐⭐ | ⭐⭐⭐⭐ | ⭐⭐⭐⭐ |
# | **Performance** | ⭐⭐⭐⭐ | ⭐⭐⭐⭐ | ⭐⭐⭐⭐ | ⭐⭐⭐⭐⭐ |
# | **Assíncrono** | ❌ (v2.0+: ✅) | ❌ | ❌ | ✅ |
# | **Migrações** | Alembic | Integrado | Sim | Aerich |
# | **Documentação** | ⭐⭐⭐⭐⭐ | ⭐⭐⭐⭐⭐ | ⭐⭐⭐⭐ | ⭐⭐⭐ |
#
# ### 🎯 **Recomendações de Uso**
#
# - **SQLAlchemy**: Projetos grandes, necessidade de controle fino, múltiplos bancos
# - **Django ORM**: Aplicações web Django, desenvolvimento rápido
# - **Peewee**: Projetos pequenos/médios, sintaxe simples
# - **Tortoise ORM**: Aplicações assíncronas (FastAPI, Starlette)

# %% [markdown]
# ## 5️⃣ Vantagens da Engenharia Reversa com ORM
#
# ---
#
# ### ✅ **Vantagens**
#
# #### 1. **Produtividade**
# - Menos código SQL manual
# - Foco na lógica de negócio
# - Desenvolvimento mais rápido
#
# #### 2. **Portabilidade**
# - Mesmo código funciona com diferentes SGBDs
# - Fácil migração entre bancos de dados
#
# #### 3. **Manutenibilidade**
# - Código mais legível e orientado a objetos
# - Mudanças centralizadas nos modelos
# - Versionamento do esquema do banco
#
# #### 4. **Segurança**
# - Proteção contra SQL Injection (queries parametrizadas)
# - Validação automática de tipos
# - Controle de acesso em nível de objeto
#
# #### 5. **Migrações Automáticas**
# - Geração automática de scripts de migração
# - Histórico de mudanças no schema
# - Rollback facilitado
#
# #### 6. **Reutilização de Código**
# - Modelos podem ser compartilhados
# - Queries podem ser abstraídas em métodos
# - Lógica de validação centralizada
#
# #### 7. **Testing**
# - Facilita testes unitários
# - Mock de banco de dados

# %% [markdown]
# ## 6️⃣ Desvantagens da Engenharia Reversa com ORM
#
# ---
#
# ### ⚠️ **Desvantagens**
#
# #### 1. **Curva de Aprendizado**
# - Necessário aprender a sintaxe do ORM
# - Entender o mapeamento objeto-relacional
# - Pode ser complexo para iniciantes
#
# #### 2. **Performance**
# - Overhead adicional na conversão objeto ↔ SQL
# - Queries geradas podem não ser otimizadas
# - N+1 queries problem (consultas desnecessárias)
#
# #### 3. **Complexidade em Queries Avançadas**
# - Queries muito complexas são difíceis de expressar
# - Às vezes é necessário usar SQL raw
# - Limitações em operações específicas do SGBD
#
# #### 4. **Abstração Excessiva**
# - Pode esconder detalhes importantes do BD
# - Dificulta otimização de queries específicas
# - Perda de controle fino sobre o SQL gerado
#
# #### 5. **Dependência de Framework**
# - Código fica acoplado ao ORM escolhido
# - Mudança de ORM pode ser custosa
# - Requer conhecimento específico da ferramenta
#
# #### 6. **Debugging**
# - Dificulta visualização das queries SQL executadas
# - Erros podem ser menos claros
# - Rastreamento de problemas de performance
#
# #### 7. **Funcionalidades Específicas do SGBD**
# - Pode não suportar recursos avançados
# - Triggers, stored procedures, views complexas
# - Tipos de dados específicos podem não ser suportados

# %% [markdown]
# ---
# ---
#
# # 💻 EXEMPLOS PRÁTICOS
#
# ---
# ---

# %% [markdown]
# ### 📖 **Antes de Executar códigp**
#
# - Crie ambiente virtual: *python -m venv venv*
# - Selecione Kernel no VS Code: I) VS atualizado II)Jupyter: ext install ms-toolsai.jupyter [atualizada]
# - Reinicie VS Code.

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: sqlalchemy>=2.0.0 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from -r requirements.txt (line 7)) (2.0.45)
# Requirement already satisfied: peewee>=3.17.0 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from -r requirements.txt (line 8)) (3.18.3)
# Requirement already satisfied: alembic>=1.13.0 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from -r requirements.txt (line 11)) (1.17.2)
# Requirement already satisfied: psycopg2-binary>=2.9.9 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from -r requirements.txt (line 14)) (2.9.11)
# Requirement already satisfied: jupyter>=1.0.0 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from -r requirements.txt (line 17)) (1.1.1)
# Requirement already satisfied: ipykernel>=6.27.0 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from -r requirements.txt (line 18)) (7.1.0)
# Requirement already satisfied: notebook>=7.0.0 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from -r requirements.txt (line 19)) (7.5.1)
# Requirement already satisfied: python-dotenv>=1.0.0 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from -r requirements.txt (line 22)) (1.2.1)
# Requirement already satisfied: greenlet>=1 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from sqlalchemy>=2.0.0->-r requirements.txt (line 7)) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from sqlalchemy>=2.0.0->-r requirements.txt (line 7)) (4.15.0)
# Requirement already satisfied: Mako in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from alembic>=1.13.0->-r requirements.txt (line 11)) (1.3.10)
# Requirement already satisfied: jupyter-console in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from jupyter>=1.0.0->-r requirements.txt (line 17)) (6.6.3)
# Requirement already satisfied: nbconvert in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from jupyter>=1.0.0->-r requirements.txt (line 17)) (7.16.6)
# Requirement already satisfied: ipywidgets in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from jupyter>=1.0.0->-r requirements.txt (line 17)) (8.1.8)
# Requirement already satisfied: jupyterlab in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from jupyter>=1.0.0->-r requirements.txt (line 17)) (4.5.1)
# Requirement already satisfied: comm>=0.1.1 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from ipykernel>=6.27.0->-r requirements.txt (line 18)) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from ipykernel>=6.27.0->-r requirements.txt (line 18)) (1.8.19)
# Requirement already satisfied: ipython>=7.23.1 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from ipykernel>=6.27.0->-r requirements.txt (line 18)) (9.8.0)
# Requirement already satisfied: jupyter-client>=8.0.0 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from ipykernel>=6.27.0->-r requirements.txt (line 18)) (8.7.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from ipykernel>=6.27.0->-r requirements.txt (line 18)) (5.9.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from ipykernel>=6.27.0->-r requirements.txt (line 18)) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from ipykernel>=6.27.0->-r requirements.txt (line 18)) (1.6.0)
# Requirement already satisfied: packaging>=22 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from ipykernel>=6.27.0->-r requirements.txt (line 18)) (25.0)
# Requirement already satisfied: psutil>=5.7 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from ipykernel>=6.27.0->-r requirements.txt (line 18)) (7.2.0)
# Requirement already satisfied: pyzmq>=25 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from ipykernel>=6.27.0->-r requirements.txt (line 18)) (27.1.0)
# Requirement already satisfied: tornado>=6.2 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from ipykernel>=6.27.0->-r requirements.txt (line 18)) (6.5.4)
# Requirement already satisfied: traitlets>=5.4.0 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from ipykernel>=6.27.0->-r requirements.txt (line 18)) (5.14.3)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from notebook>=7.0.0->-r requirements.txt (line 19)) (2.17.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from notebook>=7.0.0->-r requirements.txt (line 19)) (2.28.0)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from notebook>=7.0.0->-r requirements.txt (line 19)) (0.2.4)
# Requirement already satisfied: decorator>=4.3.2 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel>=6.27.0->-r requirements.txt (line 18)) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel>=6.27.0->-r requirements.txt (line 18)) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel>=6.27.0->-r requirements.txt (line 18)) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel>=6.27.0->-r requirements.txt (line 18)) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel>=6.27.0->-r requirements.txt (line 18)) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel>=6.27.0->-r requirements.txt (line 18)) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel>=6.27.0->-r requirements.txt (line 18)) (0.6.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from jupyter-client>=8.0.0->ipykernel>=6.27.0->-r requirements.txt (line 18)) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=6.27.0->-r requirements.txt (line 18)) (4.5.1)
# Requirement already satisfied: anyio>=3.1.0 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=7.0.0->-r requirements.txt (line 19)) (4.12.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=7.0.0->-r requirements.txt (line 19)) (25.1.0)
# Requirement already satisfied: jinja2>=3.0.3 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=7.0.0->-r requirements.txt (line 19)) (3.1.6)
# Requirement already satisfied: jupyter-events>=0.11.0 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=7.0.0->-r requirements.txt (line 19)) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=7.0.0->-r requirements.txt (line 19)) (0.5.3)
# Requirement already satisfied: nbformat>=5.3.0 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=7.0.0->-r requirements.txt (line 19)) (5.10.4)
# Requirement already satisfied: prometheus-client>=0.9 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=7.0.0->-r requirements.txt (line 19)) (0.23.1)
# Requirement already satisfied: send2trash>=1.8.2 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=7.0.0->-r requirements.txt (line 19)) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=7.0.0->-r requirements.txt (line 19)) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=7.0.0->-r requirements.txt (line 19)) (1.9.0)
# Requirement already satisfied: async-lru>=1.0.0 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 17)) (2.0.5)
# Requirement already satisfied: httpx<1,>=0.25.0 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 17)) (0.28.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 17)) (2.3.0)
# Requirement already satisfied: setuptools>=41.1.0 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 17)) (80.9.0)
# Requirement already satisfied: babel>=2.10 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.28.0->notebook>=7.0.0->-r requirements.txt (line 19)) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.28.0->notebook>=7.0.0->-r requirements.txt (line 19)) (0.12.1)
# Requirement already satisfied: jsonschema>=4.18.0 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.28.0->notebook>=7.0.0->-r requirements.txt (line 19)) (4.25.1)
# Requirement already satisfied: requests>=2.31 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.28.0->notebook>=7.0.0->-r requirements.txt (line 19)) (2.32.5)
# Requirement already satisfied: beautifulsoup4 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from nbconvert->jupyter>=1.0.0->-r requirements.txt (line 17)) (4.14.3)
# Requirement already satisfied: bleach!=5.0.0 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter>=1.0.0->-r requirements.txt (line 17)) (6.3.0)
# Requirement already satisfied: defusedxml in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from nbconvert->jupyter>=1.0.0->-r requirements.txt (line 17)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from nbconvert->jupyter>=1.0.0->-r requirements.txt (line 17)) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from nbconvert->jupyter>=1.0.0->-r requirements.txt (line 17)) (3.0.3)
# Requirement already satisfied: mistune<4,>=2.0.3 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from nbconvert->jupyter>=1.0.0->-r requirements.txt (line 17)) (3.2.0)
# Requirement already satisfied: nbclient>=0.5.0 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from nbconvert->jupyter>=1.0.0->-r requirements.txt (line 17)) (0.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from nbconvert->jupyter>=1.0.0->-r requirements.txt (line 17)) (1.5.1)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from ipywidgets->jupyter>=1.0.0->-r requirements.txt (line 17)) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from ipywidgets->jupyter>=1.0.0->-r requirements.txt (line 17)) (3.0.16)
# Requirement already satisfied: idna>=2.8 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=7.0.0->-r requirements.txt (line 19)) (3.11)
# Requirement already satisfied: argon2-cffi-bindings in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=7.0.0->-r requirements.txt (line 19)) (25.1.0)
# Requirement already satisfied: webencodings in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter>=1.0.0->-r requirements.txt (line 17)) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter>=1.0.0->-r requirements.txt (line 17)) (1.4.0)
# Requirement already satisfied: certifi in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 17)) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 17)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 17)) (0.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from jedi>=0.18.1->ipython>=7.23.1->ipykernel>=6.27.0->-r requirements.txt (line 18)) (0.8.5)
# Requirement already satisfied: attrs>=22.2.0 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook>=7.0.0->-r requirements.txt (line 19)) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook>=7.0.0->-r requirements.txt (line 19)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook>=7.0.0->-r requirements.txt (line 19)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook>=7.0.0->-r requirements.txt (line 19)) (0.30.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=7.0.0->-r requirements.txt (line 19)) (4.0.0)
# Requirement already satisfied: pyyaml>=5.3 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=7.0.0->-r requirements.txt (line 19)) (6.0.3)
# Requirement already satisfied: rfc3339-validator in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=7.0.0->-r requirements.txt (line 19)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=7.0.0->-r requirements.txt (line 19)) (0.1.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook>=7.0.0->-r requirements.txt (line 19)) (2.21.2)
# Requirement already satisfied: ptyprocess>=0.5 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel>=6.27.0->-r requirements.txt (line 18)) (0.7.0)
# Requirement already satisfied: wcwidth in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel>=6.27.0->-r requirements.txt (line 18)) (0.2.14)
# Requirement already satisfied: six>=1.5 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->jupyter-client>=8.0.0->ipykernel>=6.27.0->-r requirements.txt (line 18)) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->notebook>=7.0.0->-r requirements.txt (line 19)) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->notebook>=7.0.0->-r requirements.txt (line 19)) (2.6.2)
# Requirement already satisfied: executing>=1.2.0 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel>=6.27.0->-r requirements.txt (line 18)) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel>=6.27.0->-r requirements.txt (line 18)) (3.0.1)
# Requirement already satisfied: pure-eval in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel>=6.27.0->-r requirements.txt (line 18)) (0.2.3)
# Requirement already satisfied: soupsieve>=1.6.1 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from beautifulsoup4->nbconvert->jupyter>=1.0.0->-r requirements.txt (line 17)) (2.8.1)
# Requirement already satisfied: fqdn in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=7.0.0->-r requirements.txt (line 19)) (1.5.1)
# Requirement already satisfied: isoduration in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=7.0.0->-r requirements.txt (line 19)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=7.0.0->-r requirements.txt (line 19)) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=7.0.0->-r requirements.txt (line 19)) (1.1.0)
# Requirement already satisfied: uri-template in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=7.0.0->-r requirements.txt (line 19)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=7.0.0->-r requirements.txt (line 19)) (25.10.0)
# Requirement already satisfied: cffi>=1.0.1 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=7.0.0->-r requirements.txt (line 19)) (2.0.0)
# Requirement already satisfied: pycparser in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=7.0.0->-r requirements.txt (line 19)) (2.23)
# Requirement already satisfied: lark>=1.2.2 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=7.0.0->-r requirements.txt (line 19)) (1.3.1)
# Requirement already satisfied: arrow>=0.15.0 in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=7.0.0->-r requirements.txt (line 19)) (1.4.0)
# Requirement already satisfied: tzdata in /home/nees/Documents/VSCodigo/BancoDeDados/venv/lib/python3.12/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=7.0.0->-r requirements.txt (line 19)) (2025.3)

# %% [markdown]
# ## 🔨 Exemplo 1: SQLAlchemy - Modelo Básico
#
# Vamos criar um sistema simples de **Pessoas e Turmas** (similar ao exercício do curso).

# %%
# Instalação (descomente se necessário)
# !pip install sqlalchemy

from sqlalchemy import create_engine, Column, Integer, String, ForeignKey, Table
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import relationship, sessionmaker

# Base para os modelos
Base = declarative_base()

print("✅ SQLAlchemy importado com sucesso!")
# Out:
# ✅ SQLAlchemy importado com sucesso!
# /tmp/ipykernel_323468/1479617144.py:9: MovedIn20Warning: The ``declarative_base()`` function is now available as sqlalchemy.orm.declarative_base(). (deprecated since: 2.0) (Background on SQLAlchemy 2.0 at: https://sqlalche.me/e/b8d9)
#   Base = declarative_base()

# %% [markdown]
# ---
#
# ## Conexão com PostgreSQL (Banco Real)
#
# ### ✅ Pré-requisitos
#
# Certifique-se de que PostgreSQL está instalado e rodando:
#
# ```bash
# # Verificar se PostgreSQL está rodando
# sudo service postgresql status
#
# # Se não estiver rodando, inicie:
# sudo service postgresql start
#
# # Conectar ao banco como superusuário
# psql -U postgres
# ```
#
# ---
#
# ### 📦 Instalação do Driver PostgreSQL
#
# O SQLAlchemy precisa do `psycopg2` para conectar com PostgreSQL.
#
# ### 📋 Credenciais do Banco
#
# ```
# 🗄️ Banco: universidade
# 🖥️ Host: localhost
# 🔐 Usuário: postgres (padrão)
# 🔑 Senha: adminadmin
# 🔌 Porta: 5432 (padrão)
# ```
# # Criar a connection string

# %%
# Credenciais do banco de dados
DB_HOST = 'localhost'
DB_PORT = 5432
DB_NAME = 'universidade'
DB_USER = 'postgres'
DB_PASSWORD = 'adminadmin'
# Formato: postgresql://usuario:senha@host:porta/banco
DATABASE_URL = f'postgresql://{DB_USER}:{DB_PASSWORD}@{DB_HOST}:{DB_PORT}/{DB_NAME}'

print("📋 Connection String (sem exibir senha):")
print(f"   postgresql://***:***@{DB_HOST}:{DB_PORT}/{DB_NAME}")
print("\n✅ String de conexão criada com sucesso!")
# Out:
# 📋 Connection String (sem exibir senha):
#    postgresql://***:***@localhost:5432/universidade
#
# ✅ String de conexão criada com sucesso!

# %% [markdown]
# ### Criando a Engine SQLAlchemy

# %%
# Criar a engine (conexão com o banco PostgreSQL real)
from sqlalchemy import create_engine, text

try:
    # Criar engine com echo=True para ver as queries SQL
    engine_pg = create_engine(DATABASE_URL, echo=False)
    
    # Testar a conexão
    with engine_pg.connect() as connection:
        result = connection.execute(text("SELECT 1 as conexao"))
        print("\n✅ CONEXÃO COM POSTGRESQL ESTABELECIDA COM SUCESSO!")
        print("\n📊 Informações da Conexão:")
        print(f"   🗄️  Banco: {DB_NAME}")
        print(f"   🖥️  Host: {DB_HOST}")
        print(f"   🔌 Porta: {DB_PORT}")
        print(f"   👤 Usuário: {DB_USER}")
        print("\n💡 Engine criada e pronta para usar!")
        
except Exception as e:
    print("❌ ERRO ao conectar com PostgreSQL!")
    print(f"\n🔍 Motivo: {str(e)}")
    print("\n💡 Dicas de solução:")
    print("   1. Verifique se PostgreSQL está rodando")
    print("   2. Verifique as credenciais (usuário, senha, banco)")
    print("   3. Verifique se o banco 'universidade' existe")
    print("   4. Verifique a porta (padrão: 5432)")
# Out:
# ✅ CONEXÃO COM POSTGRESQL ESTABELECIDA COM SUCESSO!
#
# 📊 Informações da Conexão:
#    🗄️  Banco: universidade
#    🖥️  Host: localhost
#    🔌 Porta: 5432
#    👤 Usuário: postgres
#
# 💡 Engine criada e pronta para usar!

# %% [markdown]
# ---
#
# ## 📐 Diagramas Entidade-Relacionamento (E-R)
#
# Visualização do modelo de dados **Pessoa**, **Turma** e **Participante**.
#
# > **Nota:** Os diagramas abaixo foram separados para melhor visualização e evitar sobreposição de informações.
#
# ### 🎨 Diagrama E-R - Estrutura das Entidades
#
# Primeiro, vejamos a estrutura de cada entidade com seus atributos:
#
# ```mermaid
# erDiagram
#     PESSOA {
#         int cdpessoa PK
#         varchar(100) nome
#         varchar(30) fone
#     }
#
#     TURMA {
#         varchar(1) cdturma PK
#         varchar(100) nome
#         int profe FK
#     }
#
#     PARTICIPANTE {
#         int cdpessoa "PK,FK"
#         varchar(1) cdturma "PK,FK"
#     }
# ```
#
# **Legenda:**
# - 🔑 **PK** = Primary Key (Chave Primária)
# - 🔗 **FK** = Foreign Key (Chave Estrangeira)
# - **PK,FK** = Faz parte da chave primária E é chave estrangeira
#
# **Descrição dos Atributos:**
# - `PESSOA.cdpessoa`: Código único auto-incremento
# - `PESSOA.nome`: Nome completo (obrigatório)
# - `PESSOA.fone`: Telefone de contato (opcional)
# - `TURMA.cdturma`: Código da turma (A, B, C...)
# - `TURMA.nome`: Nome da disciplina
# - `TURMA.profe`: Referência ao professor (PESSOA)
# - `PARTICIPANTE.cdpessoa`: Referência ao aluno (PESSOA)
# - `PARTICIPANTE.cdturma`: Referência à turma (TURMA)

# %% [markdown]
# ### 🎯 Diagrama E-R Completo - Todos os Relacionamentos
#
# Visão geral do sistema com todos os relacionamentos:
#
# ```mermaid
# ---
# title: Sistema de Gestão Escolar
# ---
# erDiagram
#     PESSOA ||--o{ TURMA : "leciona"
#     PESSOA ||--o{ PARTICIPANTE : "matricula"
#     TURMA  ||--o{ PARTICIPANTE : "contem"
#
#     PESSOA {
#         int cdpessoa PK
#         varchar nome
#         varchar fone
#     }
#
#     TURMA {
#         varchar cdturma PK
#         varchar nome
#         int profe FK
#     }
#
#     PARTICIPANTE {
#         int cdpessoa FK
#         varchar cdturma FK
#     }
# ```
#
# **Cardinalidades:**
#
# | De → Para | Tipo | Descrição |
# |-----------|------|-----------|
# | PESSOA → TURMA | 1:N | Um professor leciona várias turmas |
# | PESSOA → PARTICIPANTE | 1:N | Um aluno tem várias matrículas |
# | TURMA → PARTICIPANTE | 1:N | Uma turma tem vários alunos |
#
# ---
#
#
# **Detalhes dos Tipos de Dados:**
#
# | Tabela | Coluna | Tipo | Constraint |
# |--------|--------|------|------------|
# | PESSOA | cdpessoa | SERIAL | PK, AUTO_INCREMENT |
# | PESSOA | nome | VARCHAR(100) | NOT NULL |
# | PESSOA | fone | VARCHAR(30) | NULL |
# | TURMA | cdturma | VARCHAR(1) | PK |
# | TURMA | nome | VARCHAR(100) | NULL |
# | TURMA | profe | INTEGER | FK → PESSOA.cdpessoa |
# | PARTICIPANTE | cdpessoa | INTEGER | PK, FK → PESSOA.cdpessoa |
# | PARTICIPANTE | cdturma | VARCHAR(1) | PK, FK → TURMA.cdturma |
#
# **Observações Importantes:**
#
# 1. ✅ `PESSOA.cdpessoa` é **SERIAL** (auto-incremento no PostgreSQL)
# 2. ✅ `PARTICIPANTE` tem **chave primária composta**: `(cdpessoa, cdturma)`
# 3. ✅ `TURMA.profe` é **OPCIONAL** (NULL permitido - turma pode não ter professor ainda)
# 4. ✅ `PESSOA.nome` é **NOT NULL** (obrigatório)
# 5. ✅ Integridade referencial garante que FK referenciem registros existentes
# 6. ✅ Não há duplicação: mesmo aluno não pode se matricular 2x na mesma turma

# %% [markdown]
# ### 📝 Definindo as Classes (Modelos)

# %%
# Tabela associativa para relacionamento N:N
participante = Table('participante', Base.metadata,
    Column('cdpessoa', Integer, ForeignKey('pessoa.cdpessoa')),
    Column('cdturma', String(1), ForeignKey('turma.cdturma'))
)

# Modelo Pessoa
class Pessoa(Base):
    __tablename__ = 'pessoa'
    
    cdpessoa = Column(Integer, primary_key=True, autoincrement=True)
    nome = Column(String(100), nullable=False)
    fone = Column(String(30))
    
    # Relacionamentos
    turmas_lecionadas = relationship('Turma', back_populates='professor')
    turmas_participadas = relationship('Turma', secondary=participante, back_populates='participantes')
    
    def __repr__(self):
        return f"<Pessoa(id={self.cdpessoa}, nome='{self.nome}')>"


# Modelo Turma
class Turma(Base):
    __tablename__ = 'turma'
    
    cdturma = Column(String(1), primary_key=True)
    nome = Column(String(100))
    profe = Column(Integer, ForeignKey('pessoa.cdpessoa'))
    
    # Relacionamentos
    professor = relationship('Pessoa', back_populates='turmas_lecionadas', foreign_keys=[profe])
    participantes = relationship('Pessoa', secondary=participante, back_populates='turmas_participadas')
    
    def __repr__(self):
        return f"<Turma(id='{self.cdturma}', nome='{self.nome}')>"

print("✅ Classes Pessoa e Turma definidas!")
print("📊 Estrutura similar ao exercício do curso implementada")
# Out:
# ✅ Classes Pessoa e Turma definidas!
# 📊 Estrutura similar ao exercício do curso implementada

# %% [markdown]
# # O que é `back_populates`?
#
# `back_populates` é um parâmetro do SQLAlchemy que **sincroniza relacionamentos bidirecionais** entre duas entidades (classes/tabelas).
#
# ---
#
# ## Na Teoria
#
# Sem `back_populates`, você teria que navegar o relacionamento em uma única direção:
#
# ```bash
# # ❌ Sem back_populates (unidirecional)
# turma = session.query(Turma).first()
# # Quem é o professor da turma?
# professor = turma.professor  # ✅ Funciona
# # Mas o inverso não funciona automaticamente
# ```

# %% [markdown]
# Com `back_populates`, o relacionamento funciona **nos dois sentidos**:
#
# ```bash
# # ✅ Com back_populates (bidirecional)
# turma = session.query(Turma).first()
# professor = turma.professor  # ✅ Funciona
#
# professor = session.query(Pessoa).first()
# # As turmas lecionadas por esse professor
# turmas = professor.turmas_lecionadas  # ✅ Funciona também!
# ```

# %% [markdown]
# ## Analogia do Mundo Real
#
# Pense em um **casal**:

# %%
João ↔️ Maria

# %% [markdown]
# - **Sem `back_populates`**: João sabe quem é seu cônjuge (Maria), mas Maria não sabe que João é seu cônjuge automaticamente
# - **Com `back_populates`**: Quando você define que João é cônjuge de Maria, automaticamente Maria sabe que João é seu cônjuge
#
# ---
#
# ## ✨ Benefícios
#
# | Benefício | Descrição |
# |-----------|-----------|
# | **Navegação Bidirecional** | Acesse relacionamentos em ambas direções |
# | **Sincronização Automática** | Mudanças se refletem nos dois lados |
# | **Código Mais Limpo** | Não precisa fazer queries extras |
# | **Integridade de Dados** | ORM mantém consistência automaticamente |

# %% [markdown]
# ### 🔄 Criando o Banco de Dados (Engenharia Reversa!)

# %%
# Criar engine (conexão com banco SQLite em memória)
engine = create_engine(DATABASE_URL, echo=False)

# 🎯 ENGENHARIA REVERSA: Classes → Tabelas [Tem que definir antes!!!]
Base.metadata.create_all(engine)

print("\n" + "="*60)
print("🎉 BANCO DE DADOS CRIADO A PARTIR DAS CLASSES!")
print("="*60)
print("\n📋 Tabelas criadas:")
print("   ✓ pessoa")
print("   ✓ turma")
print("   ✓ participante (tabela associativa)")
print("\n🔗 Relacionamentos:")
print("   ✓ turma.profe → pessoa.cdpessoa (1:N)")
print("   ✓ pessoa ←→ turma via participante (N:N)")
print("="*60)
# Out:
# ============================================================
# 🎉 BANCO DE DADOS CRIADO A PARTIR DAS CLASSES!
# ============================================================
#
# 📋 Tabelas criadas:
#    ✓ pessoa
#    ✓ turma
#    ✓ participante (tabela associativa)
#
# 🔗 Relacionamentos:
#    ✓ turma.profe → pessoa.cdpessoa (1:N)
#    ✓ pessoa ←→ turma via participante (N:N)
# ============================================================

# %% [markdown]
# ### 💾 Inserindo Dados (CRUD)

# %%
# Criar sessão
Session = sessionmaker(bind=engine)
session = Session()

# Criar pessoas
prof_maria = Pessoa(nome='Maria do Samba', fone='(11) 98765-4321')
prof_joao = Pessoa(nome='João do Rock', fone='(11) 91234-5678')
aluno1 = Pessoa(nome='Goku', fone='(11) 99999-1111')
aluno2 = Pessoa(nome='Vegeta', fone='(11) 88888-2222')
aluno3 = Pessoa(nome='Lufy', fone='(11) 77777-3333')

# Adicionar ao banco
session.add_all([prof_maria, prof_joao, aluno1, aluno2, aluno3])
session.commit()

# Criar turmas
turma_a = Turma(cdturma='A', nome='Banco de Dados')
#turma_a = Turma(cdturma='A', nome='Banco de Dados', professor=prof_maria)
turma_b = Turma(cdturma='B', nome='Programação Python', professor=prof_joao)

# Adicionar alunos às turmas
turma_a.participantes.extend([aluno1, aluno2, aluno3])
turma_b.participantes.extend([aluno1, aluno2])

turma_a.professor = prof_maria

session.add_all([turma_a, turma_b])
session.commit()

print("✅ Dados inseridos com sucesso!")
print(f"\n👥 Pessoas cadastradas: {session.query(Pessoa).count()}")
print(f"📚 Turmas criadas: {session.query(Turma).count()}")
count = session.execute(text('SELECT COUNT(*) FROM participante')).scalar()
print(f"🎓 Total de participações: {count}")
# Out:
# ✅ Dados inseridos com sucesso!
#
# 👥 Pessoas cadastradas: 5
# 📚 Turmas criadas: 2
# 🎓 Total de participações: 5

# %% [markdown]
# ### 🔍 Consultando Dados

# %%
# Listar todas as turmas com seus professores
print("📚 TURMAS E PROFESSORES:")
print("="*60)
turmas = session.query(Turma).all()
for turma in turmas:
    print(f"\n🎯 Turma {turma.cdturma}: {turma.nome}")
    print(f"   👨‍🏫 Professor: {turma.professor.nome}")
    print(f"   👥 Alunos ({len(turma.participantes)}):")
    for aluno in turma.participantes:
        print(f"      • {aluno.nome} - {aluno.fone}")

print("\n" + "="*60)

# Consultar turmas de um aluno específico
print("\n📖 TURMAS DO GOKU:")
print("="*60)
goku = session.query(Pessoa).filter_by(nome='Goku').first()
print(f"\n👤 Aluno: {goku.nome}")
print(f"📚 Turmas matriculadas:")
for turma in goku.turmas_participadas:
    print(f"   • {turma.nome} (Turma {turma.cdturma})")
print("="*60)
# Out:
# 📚 TURMAS E PROFESSORES:
# ============================================================
#
# 🎯 Turma A: Banco de Dados
#    👨‍🏫 Professor: Maria do Samba
#    👥 Alunos (3):
#       • Goku - (11) 99999-1111
#       • Vegeta - (11) 88888-2222
#       • Lufy - (11) 77777-3333
#
# 🎯 Turma B: Programação Python
#    👨‍🏫 Professor: João do Rock
#    👥 Alunos (2):
#       • Goku - (11) 99999-1111
#       • Vegeta - (11) 88888-2222
#
# ============================================================
#
# 📖 TURMAS DO GOKU:
# ============================================================
#
# 👤 Aluno: Goku
# 📚 Turmas matriculadas:
#    • Banco de Dados (Turma A)
#    • Programação Python (Turma B)
# ============================================================

# %% [markdown]
# ---
#
# ## Comparando SQL Manual vs ORM

# %% [markdown]
# ### 📊 Comparação: SQL vs ORM
#
# Vejamos a mesma operação usando **SQL puro** e depois com **ORM**:
#
# ---
#
# #### **Cenário**: Buscar todas as turmas com seus professores e alunos
#
# **🔴 Com SQL Puro:**
#
# ```sql
# -- Criar tabelas
# CREATE TABLE pessoa (
#     cdpessoa SERIAL PRIMARY KEY,
#     nome VARCHAR(100) NOT NULL,
#     fone VARCHAR(30)
# );
#
# CREATE TABLE turma (
#     cdturma VARCHAR(1) PRIMARY KEY,
#     nome VARCHAR(100),
#     profe INTEGER REFERENCES pessoa(cdpessoa)
# );
#
# CREATE TABLE participante (
#     cdpessoa INTEGER REFERENCES pessoa(cdpessoa),
#     cdturma VARCHAR(1) REFERENCES turma(cdturma)
# );
#
# -- Inserir dados
# INSERT INTO pessoa (nome, fone) VALUES ('Maria Silva', '11-9999-8888');
# INSERT INTO turma (cdturma, nome, profe) VALUES ('A', 'Banco de Dados', 1);
#
# -- Consultar (JOIN complexo)
# SELECT
#     t.nome AS turma,
#     p1.nome AS professor,
#     p2.nome AS aluno
# FROM turma t
# JOIN pessoa p1 ON t.profe = p1.cdpessoa
# LEFT JOIN participante part ON t.cdturma = part.cdturma
# LEFT JOIN pessoa p2 ON part.cdpessoa = p2.cdpessoa;
# ```
#
#
# ---
#
# ### ✨ **Vantagens Evidentes:**
#
# | Aspecto | SQL Manual | ORM |
# |---------|-----------|-----|
# | **Código** | ~30 linhas SQL | ~15 linhas Python |
# | **Legibilidade** | Complexo (JOINs) | Natural (navegação) |
# | **Manutenção** | Difícil | Fácil |
# | **Portabilidade** | Específico do SGBD | Funciona em vários |
# | **Type Safety** | ❌ | ✅ |

# %% [markdown]
# ---
#
# ## 🎯 Quando Usar ORM vs SQL Puro?
#
# ---
#
# ### 🟢 **Use ORM quando:**
#
# ✅ Desenvolvimento rápido é prioridade
# ✅ Aplicação usa múltiplos bancos de dados
# ✅ Equipe prefere POO (Programação Orientada a Objetos)
# ✅ Necessita de migrações automáticas
# ✅ Queries são relativamente simples
# ✅ Segurança contra SQL Injection é crítica
# ✅ Projeto tem muitos CRUDs básicos
#
# **Exemplos:** APIs REST, aplicações web, dashboards, sistemas CRUD
#
# ---
#
# ### 🔴 **Use SQL Puro quando:**
#
# ✅ Performance extrema é necessária
# ✅ Queries muito complexas (agregações, window functions, CTEs)
# ✅ Usa recursos específicos do SGBD (triggers, stored procedures)
# ✅ Análise de dados / Data Science (queries analíticas)
# ✅ DBA precisa otimizar queries manualmente
# ✅ Bulk operations (inserções/atualizações em massa)
#
# **Exemplos:** Data warehousing, relatórios complexos, sistemas legados
#
# ---
#
# ### 🟡 **Abordagem Híbrida (Melhor dos dois mundos):**
#
# ```python
# # Use ORM para CRUD simples
# pessoa = session.query(Pessoa).filter_by(nome='João').first()
#
# # Use SQL raw para queries complexas
# resultado = session.execute("""
#     SELECT
#         t.nome,
#         COUNT(p.cdpessoa) as total_alunos,
#         AVG(EXTRACT(YEAR FROM CURRENT_DATE) - p.ano_nascimento) as idade_media
#     FROM turma t
#     JOIN participante part ON t.cdturma = part.cdturma
#     JOIN pessoa p ON part.cdpessoa = p.cdpessoa
#     GROUP BY t.nome
#     HAVING COUNT(p.cdpessoa) > 10
# """).fetchall()
# ```
#
# ✨ **Essa é a abordagem mais usada em produção!**

# %% [markdown]
# ## 📊 Resumo Final
#
# ---
#
# ### 🎯 **Conceitos Principais**
#
# | Conceito | Descrição |
# |----------|-----------|
# | **Engenharia Reversa** | Gerar tabelas de BD a partir de classes no código |
# | **ORM** | Object-Relational Mapping - ponte entre objetos e tabelas |
# | **Migrações** | Versionamento das mudanças no schema do banco |
# | **Code-First** | Abordagem onde o código define a estrutura do BD |
#
# ---
#
# ### 📚 **Bibliotecas Python para ORM**
#
# | ORM | Melhor Para | Dificuldade |
# |-----|-------------|-------------|
# | **SQLAlchemy** | Projetos grandes e complexos | ⭐⭐⭐ |
# | **Django ORM** | Aplicações Django | ⭐ |
# | **Peewee** | Projetos pequenos/médios | ⭐⭐ |
# | **Tortoise ORM** | Apps assíncronas (FastAPI) | ⭐⭐ |
# | **Pony ORM** | Sintaxe declarativa única | ⭐⭐ |
#
# ---
#
# ### ✅ **Vantagens**
#
# - 🚀 Desenvolvimento mais rápido
# - 🔒 Maior segurança (SQL Injection)
# - 🔄 Portabilidade entre SGBDs
# - 📝 Código mais legível (OOP)
# - 🔧 Migrações automáticas
#
# ---
#
# ### ⚠️ **Desvantagens**
#
# - 📉 Overhead de performance
# - 🧩 Queries complexas são difíceis
# - 📚 Curva de aprendizado
# - 🔍 Debugging mais complexo
# - ⚙️ Menos controle sobre SQL gerado
#
# ---
#
# ### **Recomendação Final**
#
# Para a **disciplina de Banco de Dados**:
# 1. **Aprenda SQL primeiro** (fundamento essencial)
# 2. **Depois explore ORM** (ferramenta moderna)
# 3. **Use ambos conforme necessário** (abordagem híbrida)
#
# **"O melhor desenvolvedor domina tanto SQL quanto ORM e sabe quando usar cada um!"**
#
# ---
#
# ## 🔗 Recursos Adicionais
#
# - 📖 [Documentação SQLAlchemy](https://docs.sqlalchemy.org/)
# - 📖 [Documentação Django ORM](https://docs.djangoproject.com/en/stable/topics/db/)
# - 📖 [Documentação Peewee](http://docs.peewee-orm.com/)
# - 📖 [Alembic (Migrations)](https://alembic.sqlalchemy.org/)
# - 📹 [Tutorial SQLAlchemy 2.0](https://www.sqlalchemy.org/library.html)
#
# ---

# %% [markdown]
# ### ? Diagrama E-R - Relacionamento 1:N (Professor → Turma)
#
# Um professor pode lecionar várias turmas:
#
# ```mermaid
# erDiagram
#     PESSOA ||--o{ TURMA : leciona
#
#     PESSOA {
#         int cdpessoa PK
#         varchar nome
#         varchar fone
#     }
#
#     TURMA {
#         varchar cdturma PK
#         varchar nome
#         int profe FK
#     }
# ```
#
# **Interpretação:**
# - Um professor (PESSOA) pode lecionar **zero ou várias** turmas
# - Uma turma tem **exatamente um** professor
# - A relação é implementada pela FK `profe` na tabela TURMA
#
# ---
#
# ### 🔗 Diagrama E-R - Relacionamento N:N (Alunos ↔ Turmas)
#
# Vários alunos podem participar de várias turmas (via tabela associativa):
#
# ```mermaid
# erDiagram
#     PESSOA }o--o{ PARTICIPANTE : matricula
#     TURMA }o--o{ PARTICIPANTE : contem
#
#     PESSOA {
#         int cdpessoa PK
#         varchar nome
#         varchar fone
#     }
#
#     PARTICIPANTE {
#         int cdpessoa FK
#         varchar cdturma FK
#     }
#
#     TURMA {
#         varchar cdturma PK
#         varchar nome
#         int profe FK
#     }
# ```
#
# **Interpretação:**
# - Um aluno (PESSOA) pode participar de **várias** turmas
# - Uma turma pode ter **vários** alunos
# - A tabela PARTICIPANTE armazena as matrículas (relacionamento N:N)
# - Chave composta: `(cdpessoa, cdturma)`
